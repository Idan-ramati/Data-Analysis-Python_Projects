# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/ramati/Desktop/שנה ב/סמסטר ב/מבוא למדעי הנתונים/תרגיל בית 1/imdb_top_movies.csv")
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 825           826         990
# 826           827         991
# 827           828         992
# 828           829         994
# 829           830         997
#
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 825  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 826  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 827  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# ...

# %%
# 1. How many movies and attributes are in the dataset?
print(f'The dataset contains {df.shape[0]} movies and {df.shape[1]} attributes.')
# Out:
# The dataset contains 830 movies and 18 attributes.

# %%
# 2. What are the genres of movies listed from positions 4 to 9?
genres = df.iloc[3:9]['Genre']
print(genres)
# Out:
# 3        Crime
# 4        Crime
# 5       Action
# 6        Crime
# 7    Biography
# 8       Action
# Name: Genre, dtype: object

# %%
# 3. How many unique directors are there in the dataset?
num_unique_directors = df['Director'].nunique()
print(f'There are {num_unique_directors} unique directors in the dataset.')
# Out:
# There are 472 unique directors in the dataset.

# %%
# 4. How many movies have an IMDB rating above 8.0?
num_movies_above_8 = df[df['IMDB_Rating'] > 8.0].shape[0]
print(f'There are {num_movies_above_8} movies with an IMDB rating above 8.0.')
# Out:
# There are 262 movies with an IMDB rating above 8.0.

# %%
# 5. When was the most recent movie released in the dataset?
most_recent_movie = df['Released_Year'].max()
print(f'The most recent movie in the dataset was released in {most_recent_movie}.')
# Out:
# The most recent movie in the dataset was released in 2019.

# %%
# 6. What is the standard deviation of the IMDB ratings?
std_dev = df['IMDB_Rating'].std()
print(f'The standard deviation of the IMDB ratings is {std_dev}.')
# Out:
# The standard deviation of the IMDB ratings is 0.2831180189167437.

# %%
# 7. What movie received the lowest number of votes?
lowest_number_of_votes = df.loc[df['No_of_Votes'].idxmin(), 'Series_Title']
print(f'The movie with the lowest number of votes is {lowest_number_of_votes}.')
# Out:
# The movie with the lowest number of votes is Ba wang bie ji.

# %%
# 8. What is the highest Meta score?
highest_meta_score = df["Meta_score"].max()
print(f'The highest Meta score in the dataset is {highest_meta_score}.')
# Out:
# The highest Meta score in the dataset is 100.0.

# %%
# 9. What is the average number of votes received by movies in the dataset?
average_votes = df["No_of_Votes"].mean()
print(f'The average number of votes received by movies in the dataset is {average_votes}.')
# Out:
# The average number of votes received by movies in the dataset is 315305.3469879518.

# %%
# 10. How many movies grossed over $100 million?
num_movies_over_100m = df[df['Gross'] > 100000000].shape[0]
print(f'There are {num_movies_over_100m} movies that grossed over $100 million.')
# Out:
# There are 186 movies that grossed over $100 million.

# %%
# 11. Which director's movies have the highest average IMDB rating?
(df.groupby('Director')['IMDB_Rating'].mean()).idxmax()
# Out:
# 'Frank Darabont'

# %%
# 12. Which genre is the appearing the most in our dataset?
(df["Genre"].value_counts()).idxmax()
# Out:
# 'Drama'

# %%
# 1. Create a data frame of the movies that have a Meta score between 60 and 90 (inclusive).
df = pd.DataFrame(df)
df_meta_score_60_90 = df[(df['Meta_score'] >= 60) & (df['Meta_score'] <= 90)]
df_meta_score_60_90
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 2               2           2
# 3               3           3
# 8               8           8
# 9               9           9
# ..            ...         ...
# 823           824         988
# 824           825         989
# 825           826         990
# 827           828         992
# 829           830         997
#
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9    https://m.media-amazon.com/images/M/MV5BMmEzNT...
# ..                                                 ...
# 823  https://m.media-amazon.com/images/M/MV5BMjM1Nj...
# 824  https://m.media-amazon.com/images/M/MV5BYzZhOD...
# 825  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# ...

# %%
# 2. Based on the data frame you've created, display a histogram of Meta scores.
df_meta_score_60_90['Meta_score'].hist(bins=31, edgecolor='black')
plt.title('Histogram of Meta Scores')
plt.xlabel('Meta Score')
plt.ylabel('Frequency')
plt.show()

# %%
# 3. Using a Bar chart, identify which genre of movies has the highest average Gross?
# Hint: before creating the chart, you need to group the data using the aggregation function mean.

# Grouping data and calculatindg mean
df_meta_score_60_90_grouped = df_meta_score_60_90.groupby("Genre")["Gross"].mean().reset_index()

# Sorting genres by average gross in ascending order
df_meta_score_sorted = df_meta_score_60_90_grouped.sort_values(by="Gross", ascending=True)

# Creating a color list, with 'orange' for 'Action' and 'blue' for the rest
colors = ['orange' if genre == 'Action' else 'blue' for genre in df_meta_score_sorted["Genre"]]

# Plotting bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_meta_score_sorted["Genre"], df_meta_score_sorted["Gross"], color=colors)

# Function to format y-axis ticks
def format_func(value, tick_number):
    return "${:,.0f}".format(value)

plt.gca().yaxis.set_major_formatter(FuncFormatter(format_func))

plt.xlabel("Genre")
plt.ylabel("Average Gross")
plt.title("Average Gross by Genre")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
